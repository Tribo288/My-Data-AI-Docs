# %% [markdown]
# #pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Step 1: Immport

# %%
data = pd.read_csv("chipotle.tsv", sep = "\t")

# %%
data.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
data.shape
# Out:
# (4622, 5)

# %%
data.info
# Out:
# <bound method DataFrame.info of       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
list(data.columns)
# Out:
# ['order_id', 'quantity', 'item_name', 'choice_description', 'item_price']

# %%
data.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
data.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %% [markdown]
# # loc , iloc

# %%
data.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
data.loc[data.quantity > 1,["order_id","item_name"]] #and or not,...
# Out:
#       order_id           item_name
# 4            2        Chicken Bowl
# 18           9         Canned Soda
# 51          23         Canned Soda
# 135         60  Chicken Salad Bowl
# 148         67       Steak Burrito
# ...        ...                 ...
# 4491      1786   Canned Soft Drink
# 4499      1789   Canned Soft Drink
# 4560      1812   Canned Soft Drink
# 4561      1813  Chicken Salad Bowl
# 4582      1822       Bottled Water
#
# [267 rows x 2 columns]

# %%
#and or not ,....  , return specific columns,..

# %%
data.iloc[[1]]
# Out:
#    order_id  quantity item_name choice_description item_price
# 1         1         1      Izze       [Clementine]     $3.39

# %%
data.iloc[3:11]
# Out:
#     order_id  quantity                              item_name  \
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
#
#                                    choice_description item_price
# 3                                                 NaN     $2.39
# 4   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5   [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                 NaN     $1.69
# 7   [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# ...

# %%
X = data.iloc[0:5,:-1]
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description
# 0                                                NaN
# 1                                       [Clementine]
# 2                                            [Apple]
# 3                                                NaN
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...

# %% [markdown]
# #iloc["Row","Col"]

# %%
Y = data.iloc[0:5,-1]
print(Y)
# Out:
# 0     $2.39
# 1     $3.39
# 2     $3.39
# 3     $2.39
# 4    $16.98
# Name: item_price, dtype: object

# %%
data.item_price.dtype
# Out:
# dtype('O')

# %% [markdown]
# #apply()

# %%
data.item_.apply(lambda x : x.replace('$',''))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20568\261713836.py in ?()
# ----> 1 data.item_.apply( lambda x: x.replace('$',''))
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'item_'
