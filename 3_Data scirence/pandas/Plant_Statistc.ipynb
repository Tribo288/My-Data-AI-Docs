# %%
# %pip install numpy pandas matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Plant.csv")
df = df.dropna(how="all")

# %% [markdown]
# Cách 1: Bỏ dòng NaN
# df = df.dropna(how="all")
#
# Cách 2: Chỉ định rõ header
# df = pd.read_csv("Plant.csv", header=0)
#
# Cách 3 (nếu có dòng rác ở đầu file):
# df = pd.read_csv("Plant.csv", skiprows=1)
#
#
# 📌 Khuyên dùng: mở Plant.csv bằng Notepad → xóa dòng trống đầu tiên.

# %%
df.head(5)
# Out:
#                       chậu         size       giá
# 1  chậu lùn 1 gal (garden)      16 x 12  20,000 ₫
# 2          chậu nhựa vuông     6.7 x 7    3,000 ₫
# 3         chậu cao 0.5 gal    12 x 11.5  14,000 ₫
# 4           chậu cao 1 gal  15.5 x 15.5  19,000 ₫
# 5   chậu đất nung trắng x3        6 x 4  18,600 ₫

# %%
x = list(df["chậu"])
y = list(df["giá"])
plt.xlabel("tên")
plt.ylabel("Giá")
plt.bar(x,y)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\OS\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'chậu'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ...
